# %% [markdown]
# <a href="https://colab.research.google.com/github/Juuphaada/Machine-Learning-Study/blob/main/mexico_find_best_dataset%26modelsSetting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook introduction
# - Get a processed datasets and features choices from the previous notebook (mexico_dataVisualization_featureSelection.ipynb)
# - Find the best dataset and features choices for each candidate models
# - Find the best models hyperparameter
#
#
# #### **Candidate Models**
# *   Support Vector Machine (SVM)
# *   Random Forest (RF)
# *   K-Nearest Neighbors (KNNs)
# *   Artificial Neural Network (ANNs)
#
# #### **Datasets**
# *   StandardScaler dataset - dataset that features are standardized by removing the mean and scaling to unit variance.
# *   QuantileTransformer dataset - dataset that features are transformed to follow a uniform or normal distribution by mapping data to quantiles.
#
# #### **Features selection choices**
# - Set of features selected by filtering MI score
# - Set of features selected by filtering MI score & remove feature redundancy

# %% [markdown]
# # Set-up & Get data

# %%
# !pip install --upgrade scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.13/dist-packages (from scikeras) (3.13.2)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.13/dist-packages (from scikeras) (1.6.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.13/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from keras>=3.2.0->scikeras) (2.1.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.13/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.13/dist-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.13/dist-packages (from keras>=3.2.0->scikeras) (3.16.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.13/dist-packages (from keras>=3.2.0->scikeras) (0.20.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.13/dist-packages (from keras>=3.2.0->scikeras) (0.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from keras>=3.2.0->scikeras) (26.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn>=1.4.2->scikeras) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from optree->keras>=3.2.0->scikeras) (4.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich->keras>=3.2.0->scikeras) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich->keras>=3.2.0->scikeras) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %%
# !pip install "scikit-learn<1.6.0"
# Out:
# Collecting scikit-learn<1.6.0
#   Downloading scikit_learn-1.5.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.13/dist-packages (from scikit-learn<1.6.0) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn<1.6.0) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn<1.6.0) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn<1.6.0) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn<1.6.0) (3.1.2)
# Downloading scikit_learn-1.5.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 48.7 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# hdbscan 0.8.44 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# umap-learn 0.5.12 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# Successfully installed scikit-learn-1.5.2

# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score, StratifiedKFold, train_test_split, cross_validate
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from scikeras.wrappers import KerasClassifier
import numpy as np
from datetime import datetime
from dateutil import tz
date_time_stamp = datetime.now(tz=tz.tzlocal()).strftime("%Y%m%d_%H%M%S")

# %%
# get data that already processed from the previous notebook
df_std_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Researching/Maxico_std_train.csv")
df_std_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Researching/Maxico_std_test.csv")
df_trans_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Researching/Maxico_trans_train.csv")
df_trans_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Researching/Maxico_trans_test.csv")

# %%
df_std_train
# Out:
#             FOLIO_I  sexo      edad  concentracion_hemoglobina  \
# 0     2022_29007020     1  1.224349                   0.584050
# 1     2022_17011055     0  1.085882                   1.279950
# 2     2022_15033029     1  0.739716                   0.497063
# 3     2022_02002048     0 -0.160317                  -0.024862
# 4     2022_16019018     0 -0.575717                   1.366937
# ...             ...   ...       ...                        ...
# 3485  2022_25006025     0  0.462782                  -0.024862
# 3486  2022_05024003     0  0.047383                   1.366937
# 3487  2022_21114014     1  0.393549                   1.540912
# 3488  2022_27013025     0 -1.268050                   2.758736
# 3489  2022_08002026     1  1.224349                   0.671037
#
#       temperatura_ambiente  valor_acido_urico  valor_albumina  \
# 0                -4.544454          -2.057126       -1.262050
# 1                 0.193968           3.673023       -2.592937
# 2                 0.193968          -0.106437       -1.483865
# 3                 0.193968           0.015481        0.290652
# 4                 1.141652           2.210006        2.286983
# ...                    ...                ...             ...
# 3485              0.193968           0.015481        0.290652
# 3486              1.457547           1.234662        0.290652
# 3487              0.193968          -1.447536       -1.040236
# 3488              0.825758           0.015481        1.621539
# 3489             -2.964980           0.015481       -0.152977
#
#       valor_colesterol_hdl  valor_colesterol_ldl  valor_colesterol_total  ...  \
# 0                 2.470942              3.947406                2.935709  ...
# 1                 0.862396              1.151894                0.526518  ...
# 2                 0.119991              0.752535                1.341391  ...
# 3                -0.251212             -0.103234               -0.182067  ...
# 4                 3.955753              3.034586                2.900279  ...
# ...                    ...                   ...                     ...  ...
# 3485             -0.251212             -0.103234               -0.182067  ...
# 3486              0.491194              0.695484                0.526518  ...
# 3487              0.738662             -0.787849               -0.607219  ...
# 3488              1.109865              4.175611                2.581416  ...
# 3489              0.738662              1.323048                1.199674  ...
#
#       segundamedicion_peso  segundamedicion_estatura  distancia_rodilla_talon  \
# 0                 0.093873                  0.265655                -0.086564
# 1                 0.077449                  1.930072                 0.261721
# 2                -0.152489                 -0.044004                -0.066662
# 3                -0.152489                 -0.044004                -0.066662
# 4                -0.152489                 -0.044004                -0.066662
# ...                    ...                       ...                      ...
# 3485             -0.152489                 -0.044004                -0.066662
# 3486             -0.152489                 -0.044004                -0.066662
# 3487             -0.152489                 -0.044004                -0.066662
# 3488             -0.152489                 -0.044004                -0.066662
# 3489              0.553749                 -0.934273                -0.166172
#
#       circunferencia_de_la_pantorrilla  segundamedicion_cintura  \
# 0                            -0.149400                -2.162459
# 1                            -0.247558                -2.270502
# 2                            -0.113706                 0.495799
# 3                            -0.113706                 0.495799
# 4                            -0.113706                 0.495799
# ...                                ...                      ...
# 3485                         -0.113706                 0.495799
# 3486                         -0.113706                 0.495799
# 3487                         -0.113706                 0.495799
# 3488                         -0.113706                 0.495799
# 3489                          0.270003                -1.907642
#
#       tension_arterial  sueno_horas  masa_corporal  actividad_total  \
# 0            -0.181016    -0.086384      -1.742209         0.086375
# 1            -0.099796    -0.086384      -1.742209        -0.091765
# 2            -0.099796    -0.446359       0.534569         0.264516
# 3            -0.208089     0.273591       0.828710        -0.225370
# 4            -0.289310    -0.086384       0.612813         0.086375
# ...                ...          ...            ...              ...
# 3485         -0.208089     0.273591      -0.113961         0.353586
# 3486         -0.194553    -0.086384       0.613256        -0.225370
# 3487          0.292769     0.273591       0.794355         0.398121
# 3488          0.103255    -0.446359       0.864622        -0.106610
# 3489          0.184475    -0.446359      -1.742209        -0.551961
#
#       riesgo_hipertension
# 0                       0
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 3485                    0
# 3486                    1
# 3487                    1
# 3488                    1
# 3489                    1
#
# [3490 rows x 36 columns]

# %%
df_std_test
# Out:
#            FOLIO_I  sexo      edad  concentracion_hemoglobina  \
# 0    2022_02004025     0 -1.614217                  -0.024862
# 1    2022_22014004     0  0.116616                  -0.024862
# 2    2022_19031049     1 -0.091084                  -0.024862
# 3    2022_16043020     1 -0.991117                   0.149113
# 4    2022_12007020     0  1.224349                   1.453924
# ..             ...   ...       ...                        ...
# 868  2022_07087012     0 -1.752683                  -0.024862
# 869  2022_13027019     1 -0.921884                  -0.024862
# 870  2022_15106030     1  1.016649                  -0.024862
# 871  2022_06009054     1  0.047383                  -0.024862
# 872  2022_14098007     1  0.601249                   0.845012
#
#      temperatura_ambiente  valor_acido_urico  valor_albumina  \
# 0                0.193968           0.015481        0.290652
# 1                0.193968           0.015481        0.290652
# 2                0.193968           0.015481        0.290652
# 3                0.193968          -0.716028        1.177910
# 4                0.193968           0.746989       -1.705679
# ..                    ...                ...             ...
# 868              0.193968           0.015481        0.290652
# 869              0.193968           0.015481        0.290652
# 870              0.193968           0.015481        0.290652
# 871              0.193968           0.015481        0.290652
# 872             -2.333191           1.722334        0.068837
#
#      valor_colesterol_hdl  valor_colesterol_ldl  valor_colesterol_total  ...  \
# 0               -0.251212             -0.103234               -0.182067  ...
# 1               -0.251212             -0.103234               -0.182067  ...
# 2               -0.251212             -0.103234               -0.182067  ...
# 3                1.357333             -0.673746                0.207655  ...
# 4                0.243725             -0.730798               -0.500931  ...
# ..                    ...                   ...                     ...  ...
# 868             -0.251212             -0.103234               -0.182067  ...
# 869             -0.251212             -0.103234               -0.182067  ...
# 870             -0.251212             -0.103234               -0.182067  ...
# 871             -0.251212             -0.103234               -0.182067  ...
# 872              0.738662              0.923689                1.235104  ...
#
#      segundamedicion_peso  segundamedicion_estatura  distancia_rodilla_talon  \
# 0               -0.152489                 -0.044004                -0.066662
# 1               -0.152489                 -0.044004                -0.066662
# 2               -0.152489                 -0.044004                -0.066662
# 3               -0.152489                 -0.044004                -0.066662
# 4                0.854859                  1.407523                 0.022897
# ..                    ...                       ...                      ...
# 868             -0.152489                 -0.044004                -0.066662
# 869             -0.152489                 -0.044004                -0.066662
# 870             -0.075843                 -2.405153                -0.594065
# 871             -0.152489                 -0.044004                -0.066662
# 872             -0.152489                 -0.044004                -0.066662
#
#      circunferencia_de_la_pantorrilla  segundamedicion_cintura  \
# 0                           -0.113706                 0.495799
# 1                           -0.113706                 0.495799
# 2                           -0.113706                 0.495799
# 3                           -0.113706                 0.495799
# 4                            0.037993                -2.023838
# ..                                ...                      ...
# 868                         -0.113706                 0.495799
# 869                         -0.113706                 0.495799
# 870                          0.011222                 0.495799
# 871                         -0.113706                 0.495799
# 872                         -0.113706                 0.495799
#
#      tension_arterial  sueno_horas  masa_corporal  actividad_total  \
# 0           -0.181016     0.273591       0.871207        -0.002695
# 1           -0.099796    -0.806335       0.600739         0.049263
# 2            0.008498    -0.806335       0.949715         0.353586
# 3           -0.505897     0.273591      -0.086306        -0.581651
# 4            0.279232    -0.446359      -1.742209         0.086375
# ..                ...          ...            ...              ...
# 868         -0.275773     0.633566      -0.419735        -0.470314
# 869         -0.384067     0.273591       0.270801        -0.180835
# 870          0.360453     0.633566      -1.742209        -0.391635
# 871          0.076182     0.273591       0.776908        -0.514849
# 872         -0.668338     0.273591       0.873757         0.353586
#
#      riesgo_hipertension
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      0
# ..                   ...
# 868                    1
# 869                    1
# 870                    0
# 871                    1
# 872                    0
#
# [873 rows x 36 columns]

# %%
df_trans_train
# Out:
#           edad  concentracion_hemoglobina  temperatura_ambiente  \
# 0     1.210137                   1.114032             -2.696511
# 1     1.025123                   1.381364              0.079120
# 2     0.653377                   1.079690              0.079120
# 3    -0.232930                  -0.030114              0.079120
# 4    -0.523537                   1.428482              1.705570
# ...        ...                        ...                   ...
# 3485  0.378977                  -0.030114              0.079120
# 3486 -0.032625                   1.428482              1.837975
# 3487  0.312376                   1.517545              0.079120
# 3488 -1.137677                   2.107953              1.602210
# 3489  1.210137                   1.154615             -1.831224
#
#       valor_acido_urico  valor_albumina  valor_colesterol_hdl  \
# 0             -1.817968       -1.292465              1.942703
# 1              2.325972       -1.761948              1.215372
# 2             -0.977487       -1.371657              0.905189
# 3              0.046436        0.138444             -0.156199
# 4              1.798663        2.784622              2.511791
# ...                 ...             ...                   ...
# 3485           0.046436        0.138444             -0.156199
# 3486           1.494155        0.138444              1.048748
# 3487          -1.479004       -1.218002              1.157061
# 3488           0.046436        2.225823              1.321946
# 3489           0.046436       -0.965420              1.157061
#
#       valor_colesterol_ldl  valor_colesterol_total  valor_creatina  \
# 0                 2.408550                2.074445        1.035790
# 1                 1.358913                1.100140        2.797301
# 2                 1.223287                1.418119        1.154615
# 3                -0.042668               -0.096753       -0.127052
# 4                 2.063775                2.063775        2.211127
# ...                    ...                     ...             ...
# 3485             -0.042668               -0.096753       -0.127052
# 3486              1.202347                1.100140        1.750222
# 3487             -1.327982               -1.371657        1.084195
# 3488              2.492098                1.936181        1.550085
# 3489              1.442543                1.362078       -1.381364
#
#       resultado_glucosa  ...  distancia_rodilla_talon  \
# 0              1.324958  ...                -1.312981
# 1              2.427442  ...                 1.721914
# 2             -1.123415  ...                -0.016310
# 3              0.030114  ...                -0.016310
# 4              0.030114  ...                -0.016310
# ...                 ...  ...                      ...
# 3485           0.030114  ...                -0.016310
# 3486           1.324958  ...                -0.016310
# 3487           1.629992  ...                -0.016310
# 3488          -1.044409  ...                -0.016310
# 3489           1.467860  ...                -1.428482
#
#       circunferencia_de_la_pantorrilla  segundamedicion_cintura  \
# 0                            -1.625274                -1.654145
# 1                            -1.851734                -1.989660
# 2                            -0.124523                 5.199338
# 3                            -0.124523                 5.199338
# 4                            -0.124523                 5.199338
# ...                                ...                      ...
# 3485                         -0.124523                 5.199338
# 3486                         -0.124523                 5.199338
# 3487                         -0.124523                 5.199338
# 3488                         -0.124523                 5.199338
# 3489                          1.479004                -1.142483
#
#       tension_arterial  sueno_horas  masa_corporal  actividad_total  \
# 0            -0.231641    -0.195700      -5.199338         0.530745
# 1             0.080379    -0.195700      -5.199338         0.138444
# 2             0.080379    -0.823172       0.457531         0.947580
# 3            -0.391137     0.553999       1.046345        -0.184203
# 4            -0.805692    -0.195700       0.620791         0.530745
# ...                ...          ...            ...              ...
# 3485         -0.391137     0.553999      -0.599931         1.137677
# 3486         -0.283522    -0.195700       0.621466        -0.184203
# 3487          1.269664     0.553999       0.982821         1.242061
# 3488          0.741388    -0.823172       1.119649         0.090452
# 3489          1.006211    -0.823172      -5.199338        -1.497997
#
#             FOLIO_I  sexo  riesgo_hipertension
# 0     2022_29007020     2                    0
# 1     2022_17011055     1                    1
# 2     2022_15033029     2                    1
# 3     2022_02002048     1                    1
# 4     2022_16019018     1                    1
# ...             ...   ...                  ...
# 3485  2022_25006025     1                    0
# 3486  2022_05024003     1                    1
# 3487  2022_21114014     2                    1
# 3488  2022_27013025     1                    1
# 3489  2022_08002026     2                    1
#
# [3490 rows x 36 columns]

# %%
df_trans_test
# Out:
#          edad  concentracion_hemoglobina  temperatura_ambiente  \
# 0   -1.562721                  -0.030114              0.079120
# 1    0.032625                  -0.030114              0.079120
# 2   -0.163824                  -0.030114              0.079120
# 3   -0.858910                   0.951518              0.079120
# 4    1.210137                   1.467860              0.079120
# ..        ...                        ...                   ...
# 868 -1.727466                  -0.030114              0.079120
# 869 -0.809168                  -0.030114              0.079120
# 870  0.943656                  -0.030114              0.079120
# 871 -0.032625                  -0.030114              0.079120
# 872  0.516356                   1.215372             -1.597698
#
#      valor_acido_urico  valor_albumina  valor_colesterol_hdl  \
# 0             0.046436        0.138444             -0.156199
# 1             0.046436        0.138444             -0.156199
# 2             0.046436        0.138444             -0.156199
# 3            -1.174387        1.880352              1.439001
# 4             1.307063       -1.439001              0.951518
# ..                 ...             ...                   ...
# 868           0.046436        0.138444             -0.156199
# 869           0.046436        0.138444             -0.156199
# 870           0.046436        0.138444             -0.156199
# 871           0.046436        0.138444             -0.156199
# 872           1.644369       -0.892038              1.157061
#
#      valor_colesterol_ldl  valor_colesterol_total  valor_creatina  \
# 0               -0.042668               -0.096753       -0.127052
# 1               -0.042668               -0.096753       -0.127052
# 2               -0.042668               -0.096753       -0.127052
# 3               -1.283836                0.989697        1.084195
# 4               -1.304121               -1.324958        1.411293
# ..                    ...                     ...             ...
# 868             -0.042668               -0.096753       -0.127052
# 869             -0.042668               -0.096753       -0.127052
# 870             -0.042668               -0.096753       -0.127052
# 871             -0.042668               -0.096753       -0.127052
# 872              1.280981                1.381364        0.905189
#
#      resultado_glucosa  ...  distancia_rodilla_talon  \
# 0             0.030114  ...                -0.016310
# 1             0.030114  ...                -0.016310
# 2             0.030114  ...                -0.016310
# 3             1.132898  ...                -0.016310
# 4             1.223287  ...                 1.343287
# ..                 ...  ...                      ...
# 868           0.030114  ...                -0.016310
# 869           0.030114  ...                -0.016310
# 870           0.030114  ...                -2.408550
# 871           0.030114  ...                -0.016310
# 872           1.362078  ...                -0.016310
#
#      circunferencia_de_la_pantorrilla  segundamedicion_cintura  \
# 0                           -0.124523                 5.199338
# 1                           -0.124523                 5.199338
# 2                           -0.124523                 5.199338
# 3                           -0.124523                 5.199338
# 4                            1.174387                -1.315958
# ..                                ...                      ...
# 868                         -0.124523                 5.199338
# 869                         -0.124523                 5.199338
# 870                          1.135284                 5.199338
# 871                         -0.124523                 5.199338
# 872                         -0.124523                 5.199338
#
#      tension_arterial  sueno_horas  masa_corporal  actividad_total  \
# 0           -0.231641     0.553999       1.132464         0.332198
# 1            0.080379    -5.199338       0.593002         0.452955
# 2            0.457033    -5.199338       1.279050         1.137677
# 3           -1.858747     0.553999      -0.575550        -1.606755
# 4            1.236652    -0.823172      -5.199338         0.530745
# ..                ...          ...            ...              ...
# 868         -0.748009     1.554270      -0.752513        -1.081940
# 869         -1.236652     0.553999      -0.073023        -0.080379
# 870          1.435477     1.554270      -5.199338        -0.732827
# 871          0.653377     0.553999       0.954564        -1.231280
# 872         -3.034464     0.553999       1.135187         1.137677
#
#            FOLIO_I  sexo  riesgo_hipertension
# 0    2022_02004025     1                    1
# 1    2022_22014004     1                    1
# 2    2022_19031049     2                    1
# 3    2022_16043020     2                    1
# 4    2022_12007020     1                    0
# ..             ...   ...                  ...
# 868  2022_07087012     1                    1
# 869  2022_13027019     2                    1
# 870  2022_15106030     2                    0
# 871  2022_06009054     2                    1
# 872  2022_14098007     2                    0
#
# [873 rows x 36 columns]

# %%
# get standard scaler dataset
X_std_train = df_std_train.drop(columns=['FOLIO_I', 'riesgo_hipertension'])
y_std_train = df_std_train['riesgo_hipertension']
# get quartile transformer dataset
X_trans_train = df_trans_train.drop(columns=['FOLIO_I', 'riesgo_hipertension'])
y_trans_train = df_trans_train['riesgo_hipertension']

# %%
# get features selection choice from the last notebook
# selected by filtering MI score
std_selected_feature = ['masa_corporal', 'peso', 'medida_cintura', 'edad', 'estatura', 'segundamedicion_cintura', 'circunferencia_de_la_pantorrilla', 'segundamedicion_estatura', 'distancia_rodilla_talon', 'segundamedicion_peso', 'actividad_total', 'tension_arterial', 'valor_colesterol_ldl', 'valor_homocisteina', 'valor_transferrina', 'valor_trigliceridos', 'valor_vitamina_bdoce', 'valor_colesterol_total', 'valor_vitamina_d', 'valor_albumina', 'valor_ferritina', 'valor_insulina', 'valor_hemoglobina_glucosilada', 'resultado_glucosa_promedio']
trans_selected_feature = ['masa_corporal', 'peso', 'medida_cintura', 'edad', 'estatura', 'segundamedicion_cintura', 'circunferencia_de_la_pantorrilla', 'distancia_rodilla_talon', 'segundamedicion_estatura', 'segundamedicion_peso', 'actividad_total', 'tension_arterial', 'valor_transferrina', 'valor_colesterol_ldl', 'valor_homocisteina', 'valor_trigliceridos', 'valor_vitamina_bdoce', 'valor_vitamina_d', 'valor_albumina', 'resultado_glucosa', 'valor_ferritina', 'valor_insulina']
# filtering MI score & remove redundancy feature
std_selected_feature_no_redun = ['masa_corporal', 'edad', 'estatura', 'segundamedicion_cintura', 'circunferencia_de_la_pantorrilla', 'segundamedicion_estatura', 'distancia_rodilla_talon', 'segundamedicion_peso', 'actividad_total', 'tension_arterial', 'valor_colesterol_ldl', 'valor_homocisteina', 'valor_transferrina', 'valor_trigliceridos', 'valor_vitamina_bdoce', 'valor_vitamina_d', 'valor_albumina', 'valor_ferritina', 'valor_insulina', 'valor_hemoglobina_glucosilada']
trans_selected_feature_no_redun = ['masa_corporal', 'edad', 'estatura', 'segundamedicion_cintura', 'circunferencia_de_la_pantorrilla', 'distancia_rodilla_talon', 'segundamedicion_estatura', 'segundamedicion_peso', 'actividad_total', 'tension_arterial', 'valor_transferrina', 'valor_colesterol_ldl', 'valor_homocisteina', 'valor_trigliceridos', 'valor_vitamina_bdoce', 'valor_vitamina_d', 'valor_albumina', 'resultado_glucosa', 'valor_ferritina', 'valor_insulina']

# %% [markdown]
# Some models good with data that done feature selection and no feature redundancy, some models doesn't need to do feature selection on data at all.

# %% [markdown]
# # Find the best dataset & set of features
#
# ### Get CV scores from comparisons of :
# ###different dataset
# - StandardScelar dataset
# - QuantileTransformer dataset
# ### and
# ###different set of features
# - all features
# - Feature selection by filtering MI score
# - Feature selection by filtering MI score & remove feature redundancy

# %%
# define ANNs model
def create_ann_model(input_dim):
    model = Sequential([
        Input(shape=(input_dim,)),
        Dense(5, activation='relu'),
        Dense(2, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy'
    )
    return model

# %%
def cross_validation (X_train,y_train,features):
  svm_model = make_pipeline(SVC(kernel='rbf'))
  rf_model = RandomForestClassifier(n_estimators=100, random_state=42, min_samples_split=20, max_depth=15)
  knn_model = KNeighborsClassifier(n_neighbors=3)
  ann_model = KerasClassifier(model=create_ann_model(len(features)), epochs=100, batch_size=10, verbose=0)

  stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

  scoring_metrics = ['accuracy', 'precision', 'recall', 'f1']

  svm_cv_scores = cross_validate(
      estimator=svm_model,
      X=X_train[features],
      y=y_train,
      cv=stratified_kfold,
      scoring=scoring_metrics,
      return_train_score=False
  )

  rf_cv_scores = cross_validate(
      estimator=rf_model,
      X=X_train[features],
      y=y_train,
      cv=stratified_kfold,
      scoring=scoring_metrics,
      return_train_score=False
  )

  knn_cv_scores = cross_validate(
      estimator=knn_model,
      X=X_train[features],
      y=y_train,
      cv=stratified_kfold,
      scoring=scoring_metrics,
      return_train_score=False
  )

  ann_cv_scores = cross_validate(
      estimator=ann_model,
      X=X_train[features],
      y=y_train,
      cv=stratified_kfold,
      scoring=scoring_metrics,
      return_train_score=False
  )

  cv_score = pd.DataFrame(
  [
    [
      svm_cv_scores['test_accuracy'].mean(),
      rf_cv_scores['test_accuracy'].mean(),
      knn_cv_scores['test_accuracy'].mean(),
      ann_cv_scores['test_accuracy'].mean()
    ],
    [
      svm_cv_scores['test_precision'].mean(),
      rf_cv_scores['test_precision'].mean(),
      knn_cv_scores['test_precision'].mean(),
      ann_cv_scores['test_precision'].mean()
    ],
    [
      svm_cv_scores['test_recall'].mean(),
      rf_cv_scores['test_recall'].mean(),
      knn_cv_scores['test_recall'].mean(),
      ann_cv_scores['test_recall'].mean()
    ],
    [
      svm_cv_scores['test_f1'].mean(),
      rf_cv_scores['test_f1'].mean(),
      knn_cv_scores['test_f1'].mean(),
      ann_cv_scores['test_f1'].mean()
    ]
  ],
  index=[scoring_metrics],
  columns=['SVM', 'RF', 'KNNs', 'ANNs'])

  return cv_score

# %% [markdown]
# Using dataset with all features

# %%
stdData_cv_score = cross_validation(X_std_train,y_std_train,X_std_train.columns);
transData_cv_score = cross_validation(X_trans_train,y_trans_train,X_trans_train.columns);
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# save result
stdData_cv_score.to_csv(f'/content/drive/MyDrive/Colab Notebooks/Researching/compare_std_trans/stdData_cv_score_{date_time_stamp}.csv', index=True)
transData_cv_score.to_csv(f'/content/drive/MyDrive/Colab Notebooks/Researching/compare_std_trans/transData_cv_score_{date_time_stamp}.csv', index=True)

# %% [markdown]
# Using dataset with feature selection by filtering MI score

# %%
trans_cv_score_selectedfeature = cross_validation(X_trans_train,y_trans_train,trans_selected_feature);
std_cv_score_selectedfeature = cross_validation(X_std_train,y_std_train,std_selected_feature);
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
std_cv_score_selectedfeature.to_csv(f'/content/drive/MyDrive/Colab Notebooks/Researching/compare_std_trans/std_cv_score_selectedfeature{date_time_stamp}.csv', index=True)
trans_cv_score_selectedfeature.to_csv(f'/content/drive/MyDrive/Colab Notebooks/Researching/compare_std_trans/trans_cv_score_selectedfeature{date_time_stamp}.csv', index=True)

# %% [markdown]
# Using dataset with feature selection by filtering MI score & remove feature redundancy

# %%
std_cv_score_selectedfeature_no_redun = cross_validation(X_std_train,y_std_train,std_selected_feature_no_redun);
trans_cv_score_selectedfeature_no_redun = cross_validation(X_trans_train,y_trans_train,trans_selected_feature_no_redun);
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
std_cv_score_selectedfeature_no_redun.to_csv(f'/content/drive/MyDrive/Colab Notebooks/Researching/compare_std_trans/std_cv_score_selectedfeature_no_redun{date_time_stamp}.csv', index=True)
trans_cv_score_selectedfeature_no_redun.to_csv(f'/content/drive/MyDrive/Colab Notebooks/Researching/compare_std_trans/trans_cv_score_selectedfeature_no_redun{date_time_stamp}.csv', index=True)

# %% [markdown]
# # Get Best CV score (recall)
# ### Why Recall
# For predicting the risk of hypertension in persons, false negative case is more costly than false positive case.
#
#
# More recall score = less false negative.

# %%
stdData_cv_score
# Out:
#                 SVM        RF      KNNs      ANNs
# accuracy   0.849857  0.985673  0.815186  0.897135
# precision  0.855740  0.994622  0.841370  0.911849
# recall     0.923174  0.983128  0.879663  0.930734
# f1         0.888118  0.988836  0.860022  0.921143

# %%
transData_cv_score
# Out:
#                 SVM        RF      KNNs      ANNs
# accuracy   0.880229  0.986533  0.861891  0.931805
# precision  0.899193  0.995964  0.881469  0.943020
# recall     0.917405  0.983129  0.908089  0.952050
# f1         0.908150  0.989498  0.894563  0.947477

# %%
std_cv_score_selectedfeature
# Out:
#                 SVM        RF      KNNs      ANNs
# accuracy   0.858739  0.987679  0.836103  0.878797
# precision  0.869801  0.996407  0.855293  0.898120
# recall     0.918738  0.984460  0.898325  0.916082
# f1         0.893556  0.990397  0.876112  0.907001

# %%
trans_cv_score_selectedfeature
# Out:
#                 SVM        RF      KNNs      ANNs
# accuracy   0.892837  0.987679  0.881662  0.892837
# precision  0.910251  0.998195  0.897267  0.904040
# recall     0.925398  0.982685  0.922293  0.932964
# f1         0.917681  0.990376  0.909576  0.918207

# %%
std_cv_score_selectedfeature_no_redun
# Out:
#                 SVM        RF      KNNs      ANNs
# accuracy   0.852722  0.987679  0.835244  0.887966
# precision  0.860954  0.998196  0.854866  0.912936
# recall     0.920512  0.982684  0.896992  0.913853
# f1         0.889709  0.990376  0.875381  0.913290

# %%
trans_cv_score_selectedfeature_no_redun
# Out:
#                 SVM        RF      KNNs      ANNs
# accuracy   0.882521  0.988539  0.870201  0.956734
# precision  0.895757  0.999099  0.889694  0.967224
# recall     0.925853  0.983129  0.912086  0.965808
# f1         0.910471  0.991046  0.900692  0.966466

# %% [markdown]
# ### **Result**
#
# #### The best choises for each model ( for getting highest CV score of recall )
# - SVM : Use QuantileTransformer dataset + feature selection & remove redundancy feature
# - RF : Use QuantileTransformer dataset with using all features
# - KNNs : Use QuantileTransformer dataset + feature selection
# - ANNs : Use QuantileTransformer dataset + feature selection & remove redundancy feature

# %% [markdown]
# # Find the best models hyperparameter
# Find the best setting of models parameters by iteration thru a range of values pair with values from other ranges, and get the pair with best CV score of recall.
#
#
# #### Searching Method
# - GridSearchCV : Evaluates all combinations.
# - RandomizedSearchCV : Evaluates a subset of hyperparameter combinations.

# %% [markdown]
# Use
# - SVM : GridSearch
# - RF : RandomSearch + GridSearch
# - KNNs : GraidSearch
# - ANNs : RandomSearch + GridSearch

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, loguniform
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
# define base ANNs model
def create_custom_ann_model(input_dim, L1_units, L2_units, alpha, learning_rate_init):
    model = Sequential([
        Input(shape=(input_dim,)),
        Dense(L1_units, activation='relu'),
        Dense(L2_units, activation='softmax', kernel_regularizer=l2(alpha))
    ])

    model.compile(
        optimizer=Adam(learning_rate=learning_rate_init),
        loss='sparse_categorical_crossentropy'
    )
    return model

# %%
# created base model
custom_svm_model = SVC(kernel = 'rbf')
custom_rf_model = RandomForestClassifier(random_state=42)
custom_knn_model = KNeighborsClassifier()
custom_ann_model = KerasClassifier(model=create_custom_ann_model, input_dim=len(trans_selected_feature_no_redun), epochs=100)

# %% [markdown]
# ### SVM

# %%
def svm_grid_search (svm_model, X, y):

  svm_params = {'C': [1,10,50,100,110], 'gamma': ['scale','auto']}

  Searching = GridSearchCV(custom_rf_model, svm_params ,cv=stratified_kfold, scoring='recall',refit=False,verbose = 5)
  Searching.fit(X, y)

  return Searching.best_params_ , Searching.best_score_

svm_grid_best_params, svm_grid_best_score = svm_grid_search(custom_svm_model, X_trans_train[trans_selected_feature_no_redun], y_trans_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END ..................C=1, gamma=scale;, score=0.942 total time=   0.2s
# [CV 2/5] END ..................C=1, gamma=scale;, score=0.938 total time=   0.2s
# [CV 3/5] END ..................C=1, gamma=scale;, score=0.918 total time=   0.2s
# [CV 4/5] END ..................C=1, gamma=scale;, score=0.914 total time=   0.2s
# [CV 5/5] END ..................C=1, gamma=scale;, score=0.918 total time=   0.2s
# [CV 1/5] END ...................C=1, gamma=auto;, score=0.940 total time=   0.2s
# [CV 2/5] END ...................C=1, gamma=auto;, score=0.942 total time=   0.2s
# [CV 3/5] END ...................C=1, gamma=auto;, score=0.927 total time=   0.2s
# [CV 4/5] END ...................C=1, gamma=auto;, score=0.929 total time=   0.2s
# [CV 5/5] END ...................C=1, gamma=auto;, score=0.936 total time=   0.2s
# [CV 1/5] END .................C=10, gamma=scale;, score=0.940 total time=   0.4s
# [CV 2/5] END .................C=10, gamma=scale;, score=0.947 total time=   0.5s
# [CV 3/5] END .................C=10, gamma=scale;, score=0.944 total time=   0.3s
# [CV 4/5] END .................C=10, gamma=scale;, score=0.947 total time=   0.6s
# [CV 5/5] END .................C=10, gamma=scale;, score=0.940 total time=   0.4s
# [CV 1/5] END ..................C=10, gamma=auto;, score=0.949 total time=   0.4s
# [CV 2/5] END ..................C=10, gamma=auto;, score=0.944 total time=   0.5s
# [CV 3/5] END ..................C=10, gamma=auto;, score=0.944 total time=   0.4s
# [CV 4/5] END ..................C=10, gamma=auto;, score=0.933 total time=   0.2s
# [CV 5/5] END ..................C=10, gamma=auto;, score=0.933 total time=   0.2s
# [CV 1/5] END .................C=50, gamma=scale;, score=0.953 total time=   0.1s
# [CV 2/5] END .................C=50, gamma=scale;, score=0.947 total time=   0.2s
# [CV 3/5] END .................C=50, gamma=scale;, score=0.956 total time=   0.2s
# [CV 4/5] END .................C=50, gamma=scale;, score=0.945 total time=   0.3s
# [CV 5/5] END .................C=50, gamma=scale;, score=0.947 total time=   0.3s
# [CV 1/5] END ..................C=50, gamma=auto;, score=0.960 total time=   0.2s
# [CV 2/5] END ..................C=50, gamma=auto;, score=0.951 total time=   0.2s
# [CV 3/5] END ..................C=50, gamma=auto;, score=0.947 total time=   0.3s
# [CV 4/5] END ..................C=50, gamma=auto;, score=0.936 total time=   0.3s
# [CV 5/5] END ..................C=50, gamma=auto;, score=0.945 total time=   0.2s
# [CV 1/5] END ................C=100, gamma=scale;, score=0.951 total time=   0.3s
# [CV 2/5] END ................C=100, gamma=scale;, score=0.953 total time=   0.3s
# [CV 3/5] END ................C=100, gamma=scale;, score=0.956 total time=   0.3s
# [CV 4/5] END ................C=100, gamma=scale;, score=0.947 total time=   0.2s
# [CV 5/5] END ................C=100, gamma=scale;, score=0.945 total time=   0.3s
# [CV 1/5] END .................C=100, gamma=auto;, score=0.960 total time=   0.3s
# [CV 2/5] END .................C=100, gamma=auto;, score=0.956 total time=   0.3s
# [CV 3/5] END .................C=100, gamma=auto;, score=0.949 total time=   0.3s
# [CV 4/5] END .................C=100, gamma=auto;, score=0.942 total time=   0.3s
# [CV 5/5] END .................C=100, gamma=auto;, score=0.945 total time=   0.2s
# [CV 1/5] END ................C=110, gamma=scale;, score=0.949 total time=   0.2s
# [CV 2/5] END ................C=110, gamma=scale;, score=0.951 total time=   0.2s
# [CV 3/5] END ................C=110, gamma=scale;, score=0.958 total time=   0.2s
# [CV 4/5] END ................C=110, gamma=scale;, score=0.942 total time=   0.2s
# [CV 5/5] END ................C=110, gamma=scale;, score=0.942 total time=   0.2s
# [CV 1/5] END .................C=110, gamma=auto;, score=0.960 total time=   0.1s
# [CV 2/5] END .................C=110, gamma=auto;, score=0.956 total time=   0.2s
# [CV 3/5] END .................C=110, gamma=auto;, score=0.949 total time=   0.2s
# [CV 4/5] END .................C=110, gamma=auto;, score=0.940 total time=   0.2s
# [CV 5/5] END .................C=110, gamma=auto;, score=0.942 total time=   0.2s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=SVC(),
#              param_grid={'C': [1, 10, 50, 100, 110],
#                          'gamma': ['scale', 'auto']},
#              refit=False, scoring='recall', verbose=5)

# %%
print(svm_grid_best_params)
print(svm_grid_best_score)
# Out:
# {'C': 100, 'gamma': 'auto'}
# 0.9502724809066272

# %% [markdown]
# ### RF

# %%
def rf_random_search (rf_model, X, y):
  rf_params = {
   'max_depth': list(range(5, 15)) + [None],
   'max_features': range(5,15),
   'min_samples_leaf': range(5,15),
   'min_samples_split': [5, 10, 15, 20],
   'n_estimators': [100,200,300,400,500]
  }

  Searching = RandomizedSearchCV(rf_model, rf_params, cv=stratified_kfold, scoring='recall',verbose = 5)
  Searching.fit(X, y)

  return Searching.best_params_ , Searching.best_score_

rf_bestRandom_params, rf_bestRandom_score = rf_random_search(custom_rf_model, X_trans_train, y_trans_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END max_depth=11, max_features=6, min_samples_leaf=11, min_samples_split=5, n_estimators=400;, score=0.989 total time=   3.3s
# [CV 2/5] END max_depth=11, max_features=6, min_samples_leaf=11, min_samples_split=5, n_estimators=400;, score=0.980 total time=   2.5s
# [CV 3/5] END max_depth=11, max_features=6, min_samples_leaf=11, min_samples_split=5, n_estimators=400;, score=0.976 total time=   2.4s
# [CV 4/5] END max_depth=11, max_features=6, min_samples_leaf=11, min_samples_split=5, n_estimators=400;, score=0.980 total time=   2.7s
# [CV 5/5] END max_depth=11, max_features=6, min_samples_leaf=11, min_samples_split=5, n_estimators=400;, score=0.980 total time=   1.9s
# [CV 1/5] END max_depth=8, max_features=14, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.0s
# [CV 2/5] END max_depth=8, max_features=14, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.982 total time=   2.8s
# [CV 3/5] END max_depth=8, max_features=14, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.984 total time=   2.6s
# [CV 4/5] END max_depth=8, max_features=14, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.0s
# [CV 5/5] END max_depth=8, max_features=14, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.987 total time=   2.0s
# [CV 1/5] END max_depth=6, max_features=14, min_samples_leaf=14, min_samples_split=10, n_estimators=100;, score=0.989 total time=   0.6s
# [CV 2/5] END max_depth=6, max_features=14, min_samples_leaf=14, min_samples_split=10, n_estimators=100;, score=0.982 total time=   0.6s
# [CV 3/5] END max_depth=6, max_features=14, min_samples_leaf=14, min_samples_split=10, n_estimators=100;, score=0.982 total time=   0.6s
# [CV 4/5] END max_depth=6, max_features=14, min_samples_leaf=14, min_samples_split=10, n_estimators=100;, score=0.987 total time=   0.7s
# [CV 5/5] END max_depth=6, max_features=14, min_samples_leaf=14, min_samples_split=10, n_estimators=100;, score=0.984 total time=   0.6s
# [CV 1/5] END max_depth=9, max_features=6, min_samples_leaf=12, min_samples_split=20, n_estimators=400;, score=0.989 total time=   1.9s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_leaf=12, min_samples_split=20, n_estimators=400;, score=0.980 total time=   2.6s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_leaf=12, min_samples_split=20, n_estimators=400;, score=0.976 total time=   2.6s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_leaf=12, min_samples_split=20, n_estimators=400;, score=0.978 total time=   1.9s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_leaf=12, min_samples_split=20, n_estimators=400;, score=0.982 total time=   2.7s
# [CV 1/5] END max_depth=14, max_features=14, min_samples_leaf=11, min_samples_split=15, n_estimators=300;, score=0.989 total time=   2.2s
# [CV 2/5] END max_depth=14, max_features=14, min_samples_leaf=11, min_samples_split=15, n_estimators=300;, score=0.982 total time=   3.3s
# [CV 3/5] END max_depth=14, max_features=14, min_samples_leaf=11, min_samples_split=15, n_estimators=300;, score=0.984 total time=   4.8s
# [CV 4/5] END max_depth=14, max_features=14, min_samples_leaf=11, min_samples_split=15, n_estimators=300;, score=0.989 total time=   2.8s
# [CV 5/5] END max_depth=14, max_features=14, min_samples_leaf=11, min_samples_split=15, n_estimators=300;, score=0.987 total time=   2.5s
# [CV 1/5] END max_depth=10, max_features=14, min_samples_leaf=13, min_samples_split=10, n_estimators=400;, score=0.989 total time=   3.0s
# [CV 2/5] END max_depth=10, max_features=14, min_samples_leaf=13, min_samples_split=10, n_estimators=400;, score=0.982 total time=   6.6s
# [CV 3/5] END max_depth=10, max_features=14, min_samples_leaf=13, min_samples_split=10, n_estimators=400;, score=0.984 total time=   4.0s
# [CV 4/5] END max_depth=10, max_features=14, min_samples_leaf=13, min_samples_split=10, n_estimators=400;, score=0.984 total time=   4.2s
# [CV 5/5] END max_depth=10, max_features=14, min_samples_leaf=13, min_samples_split=10, n_estimators=400;, score=0.987 total time=   5.1s
# [CV 1/5] END max_depth=14, max_features=13, min_samples_leaf=12, min_samples_split=10, n_estimators=200;, score=0.989 total time=   2.1s
# [CV 2/5] END max_depth=14, max_features=13, min_samples_leaf=12, min_samples_split=10, n_estimators=200;, score=0.982 total time=   1.9s
# [CV 3/5] END max_depth=14, max_features=13, min_samples_leaf=12, min_samples_split=10, n_estimators=200;, score=0.984 total time=   2.4s
# [CV 4/5] END max_depth=14, max_features=13, min_samples_leaf=12, min_samples_split=10, n_estimators=200;, score=0.982 total time=   1.3s
# [CV 5/5] END max_depth=14, max_features=13, min_samples_leaf=12, min_samples_split=10, n_estimators=200;, score=0.982 total time=   2.0s
# [CV 1/5] END max_depth=14, max_features=13, min_samples_leaf=14, min_samples_split=5, n_estimators=100;, score=0.989 total time=   0.8s
# [CV 2/5] END max_depth=14, max_features=13, min_samples_leaf=14, min_samples_split=5, n_estimators=100;, score=0.982 total time=   0.9s
# [CV 3/5] END max_depth=14, max_features=13, min_samples_leaf=14, min_samples_split=5, n_estimators=100;, score=0.978 total time=   1.2s
# [CV 4/5] END max_depth=14, max_features=13, min_samples_leaf=14, min_samples_split=5, n_estimators=100;, score=0.980 total time=   1.1s
# [CV 5/5] END max_depth=14, max_features=13, min_samples_leaf=14, min_samples_split=5, n_estimators=100;, score=0.980 total time=   1.1s
# [CV 1/5] END max_depth=6, max_features=10, min_samples_leaf=13, min_samples_split=10, n_estimators=400;, score=0.989 total time=   3.6s
# [CV 2/5] END max_depth=6, max_features=10, min_samples_leaf=13, min_samples_split=10, n_estimators=400;, score=0.982 total time=   2.8s
# [CV 3/5] END max_depth=6, max_features=10, min_samples_leaf=13, min_samples_split=10, n_estimators=400;, score=0.980 total time=   2.7s
# [CV 4/5] END max_depth=6, max_features=10, min_samples_leaf=13, min_samples_split=10, n_estimators=400;, score=0.980 total time=   2.2s
# [CV 5/5] END max_depth=6, max_features=10, min_samples_leaf=13, min_samples_split=10, n_estimators=400;, score=0.982 total time=   5.1s
# [CV 1/5] END max_depth=7, max_features=9, min_samples_leaf=12, min_samples_split=20, n_estimators=500;, score=0.989 total time=   3.8s
# [CV 2/5] END max_depth=7, max_features=9, min_samples_leaf=12, min_samples_split=20, n_estimators=500;, score=0.982 total time=   3.0s
# [CV 3/5] END max_depth=7, max_features=9, min_samples_leaf=12, min_samples_split=20, n_estimators=500;, score=0.982 total time=   2.7s
# [CV 4/5] END max_depth=7, max_features=9, min_samples_leaf=12, min_samples_split=20, n_estimators=500;, score=0.980 total time=   3.6s
# [CV 5/5] END max_depth=7, max_features=9, min_samples_leaf=12, min_samples_split=20, n_estimators=500;, score=0.980 total time=   3.3s

# %%
print(rf_bestRandom_params)
print(rf_bestRandom_score)
# Out:
# {'n_estimators': 300, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': 14, 'max_depth': 8}
# 0.9862330623306234

# %%
def rf_grid_search (bestRandom_params, rf_model, X, y):
  max_depth = bestRandom_params['max_depth']
  max_features = bestRandom_params['max_features']
  min_samples_leaf = bestRandom_params['min_samples_leaf']
  min_samples_split = bestRandom_params['min_samples_split']
  n_estimators = bestRandom_params['n_estimators']

  rf_params = {
    'max_depth': [max_depth],
    'max_features': range(max_features-2,max_features+2),
    'min_samples_leaf': range(min_samples_leaf-2,min_samples_leaf+2),
    'min_samples_split': [min_samples_split],
    'n_estimators': [n_estimators]
  }

  Searching = GridSearchCV(rf_model, rf_params ,cv=stratified_kfold, scoring='recall',refit=False,verbose = 5)
  Searching.fit(X, y)

  return Searching.best_params_ , Searching.best_score_;


rf_grid_best_params, rf_grid_best_score = rf_grid_search(rf_bestRandom_params, custom_rf_model, X_trans_train, y_trans_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END max_depth=8, max_features=12, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.0s
# [CV 2/5] END max_depth=8, max_features=12, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.982 total time=   1.9s
# [CV 3/5] END max_depth=8, max_features=12, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.984 total time=   1.9s
# [CV 4/5] END max_depth=8, max_features=12, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.989 total time=   1.9s
# [CV 5/5] END max_depth=8, max_features=12, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.984 total time=   2.5s
# [CV 1/5] END max_depth=8, max_features=12, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.7s
# [CV 2/5] END max_depth=8, max_features=12, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.982 total time=   1.9s
# [CV 3/5] END max_depth=8, max_features=12, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.984 total time=   1.9s
# [CV 4/5] END max_depth=8, max_features=12, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.982 total time=   1.9s
# [CV 5/5] END max_depth=8, max_features=12, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.984 total time=   1.9s
# [CV 1/5] END max_depth=8, max_features=12, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.989 total time=   1.9s
# [CV 2/5] END max_depth=8, max_features=12, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.982 total time=   2.5s
# [CV 3/5] END max_depth=8, max_features=12, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.984 total time=   2.6s
# [CV 4/5] END max_depth=8, max_features=12, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.980 total time=   1.9s
# [CV 5/5] END max_depth=8, max_features=12, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.984 total time=   1.9s
# [CV 1/5] END max_depth=8, max_features=12, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.0s
# [CV 2/5] END max_depth=8, max_features=12, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.982 total time=   1.8s
# [CV 3/5] END max_depth=8, max_features=12, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.984 total time=   1.9s
# [CV 4/5] END max_depth=8, max_features=12, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.980 total time=   2.5s
# [CV 5/5] END max_depth=8, max_features=12, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.984 total time=   2.6s
# [CV 1/5] END max_depth=8, max_features=13, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.7s
# [CV 2/5] END max_depth=8, max_features=13, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.982 total time=   3.0s
# [CV 3/5] END max_depth=8, max_features=13, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.984 total time=   2.0s
# [CV 4/5] END max_depth=8, max_features=13, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.987 total time=   2.0s
# [CV 5/5] END max_depth=8, max_features=13, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.984 total time=   2.7s
# [CV 1/5] END max_depth=8, max_features=13, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.6s
# [CV 2/5] END max_depth=8, max_features=13, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.982 total time=   1.9s
# [CV 3/5] END max_depth=8, max_features=13, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.984 total time=   2.0s
# [CV 4/5] END max_depth=8, max_features=13, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.982 total time=   2.0s
# [CV 5/5] END max_depth=8, max_features=13, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.982 total time=   2.1s
# [CV 1/5] END max_depth=8, max_features=13, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.1s
# [CV 2/5] END max_depth=8, max_features=13, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.982 total time=   2.8s
# [CV 3/5] END max_depth=8, max_features=13, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.984 total time=   2.3s
# [CV 4/5] END max_depth=8, max_features=13, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.982 total time=   1.9s
# [CV 5/5] END max_depth=8, max_features=13, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.982 total time=   2.6s
# [CV 1/5] END max_depth=8, max_features=13, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.3s
# [CV 2/5] END max_depth=8, max_features=13, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.980 total time=   2.0s
# [CV 3/5] END max_depth=8, max_features=13, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.980 total time=   2.7s
# [CV 4/5] END max_depth=8, max_features=13, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.980 total time=   3.9s
# [CV 5/5] END max_depth=8, max_features=13, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.980 total time=   2.1s
# [CV 1/5] END max_depth=8, max_features=14, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.3s
# [CV 2/5] END max_depth=8, max_features=14, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.982 total time=   2.0s
# [CV 3/5] END max_depth=8, max_features=14, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.987 total time=   2.1s
# [CV 4/5] END max_depth=8, max_features=14, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.989 total time=   3.0s
# [CV 5/5] END max_depth=8, max_features=14, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.987 total time=   2.5s
# [CV 1/5] END max_depth=8, max_features=14, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.0s
# [CV 2/5] END max_depth=8, max_features=14, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.982 total time=   1.9s
# [CV 3/5] END max_depth=8, max_features=14, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.984 total time=   2.0s
# [CV 4/5] END max_depth=8, max_features=14, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.0s
# [CV 5/5] END max_depth=8, max_features=14, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.987 total time=   2.5s
# [CV 1/5] END max_depth=8, max_features=14, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.9s
# [CV 2/5] END max_depth=8, max_features=14, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.982 total time=   2.1s
# [CV 3/5] END max_depth=8, max_features=14, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.984 total time=   2.0s
# [CV 4/5] END max_depth=8, max_features=14, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.1s
# [CV 5/5] END max_depth=8, max_features=14, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.987 total time=   2.6s
# [CV 1/5] END max_depth=8, max_features=14, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.1s
# [CV 2/5] END max_depth=8, max_features=14, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.982 total time=   2.9s
# [CV 3/5] END max_depth=8, max_features=14, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.984 total time=   2.4s
# [CV 4/5] END max_depth=8, max_features=14, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.982 total time=   2.0s
# [CV 5/5] END max_depth=8, max_features=14, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.984 total time=   2.0s
# [CV 1/5] END max_depth=8, max_features=15, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.1s
# [CV 2/5] END max_depth=8, max_features=15, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.982 total time=   2.6s
# [CV 3/5] END max_depth=8, max_features=15, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.987 total time=   5.2s
# [CV 4/5] END max_depth=8, max_features=15, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.2s
# [CV 5/5] END max_depth=8, max_features=15, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.987 total time=   3.3s
# [CV 1/5] END max_depth=8, max_features=15, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.3s
# [CV 2/5] END max_depth=8, max_features=15, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.982 total time=   2.2s
# [CV 3/5] END max_depth=8, max_features=15, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.984 total time=   4.6s
# [CV 4/5] END max_depth=8, max_features=15, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.989 total time=   3.0s
# [CV 5/5] END max_depth=8, max_features=15, min_samples_leaf=11, min_samples_split=20, n_estimators=300;, score=0.987 total time=   2.1s
# [CV 1/5] END max_depth=8, max_features=15, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.0s
# [CV 2/5] END max_depth=8, max_features=15, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.982 total time=   2.7s
# [CV 3/5] END max_depth=8, max_features=15, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.984 total time=   3.8s
# [CV 4/5] END max_depth=8, max_features=15, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.5s
# [CV 5/5] END max_depth=8, max_features=15, min_samples_leaf=12, min_samples_split=20, n_estimators=300;, score=0.987 total time=   2.8s
# [CV 1/5] END max_depth=8, max_features=15, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.989 total time=   2.6s
# [CV 2/5] END max_depth=8, max_features=15, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.982 total time=   2.4s
# [CV 3/5] END max_depth=8, max_features=15, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.984 total time=   4.1s
# [CV 4/5] END max_depth=8, max_features=15, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.987 total time=   3.5s
# [CV 5/5] END max_depth=8, max_features=15, min_samples_leaf=13, min_samples_split=20, n_estimators=300;, score=0.987 total time=   3.1s

# %%
print(rf_grid_best_params)
print(rf_grid_best_score)
# Out:
# {'max_depth': 8, 'max_features': 14, 'min_samples_leaf': 10, 'min_samples_split': 20, 'n_estimators': 300}
# 0.9866775067750677

# %% [markdown]
# ### KNNs

# %%
def knn_grid_search (knn_model, X, y):

  knn_params = {'n_neighbors': list(range(3, 11)),
                'weights': ['uniform', 'distance'],
                'p': [1, 2]}

  Searching = GridSearchCV(knn_model, knn_params, cv=stratified_kfold, scoring='recall',verbose = 5)
  Searching.fit(X, y)

  return Searching.best_params_ , Searching.best_score_

knn_grid_best_params, knn_grid_best_score = knn_grid_search(custom_knn_model, X_trans_train[trans_selected_feature], y_trans_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5] END n_neighbors=3, p=1, weights=uniform;, score=0.927 total time=   0.1s
# [CV 2/5] END n_neighbors=3, p=1, weights=uniform;, score=0.922 total time=   0.1s
# [CV 3/5] END n_neighbors=3, p=1, weights=uniform;, score=0.916 total time=   0.0s
# [CV 4/5] END n_neighbors=3, p=1, weights=uniform;, score=0.920 total time=   0.1s
# [CV 5/5] END n_neighbors=3, p=1, weights=uniform;, score=0.931 total time=   0.0s
# [CV 1/5] END n_neighbors=3, p=1, weights=distance;, score=0.924 total time=   0.0s
# [CV 2/5] END n_neighbors=3, p=1, weights=distance;, score=0.920 total time=   0.0s
# [CV 3/5] END n_neighbors=3, p=1, weights=distance;, score=0.913 total time=   0.1s
# [CV 4/5] END n_neighbors=3, p=1, weights=distance;, score=0.920 total time=   0.1s
# [CV 5/5] END n_neighbors=3, p=1, weights=distance;, score=0.931 total time=   0.1s
# [CV 1/5] END n_neighbors=3, p=2, weights=uniform;, score=0.924 total time=   0.0s
# [CV 2/5] END n_neighbors=3, p=2, weights=uniform;, score=0.922 total time=   0.0s
# [CV 3/5] END n_neighbors=3, p=2, weights=uniform;, score=0.924 total time=   0.0s
# [CV 4/5] END n_neighbors=3, p=2, weights=uniform;, score=0.927 total time=   0.0s
# [CV 5/5] END n_neighbors=3, p=2, weights=uniform;, score=0.914 total time=   0.0s
# [CV 1/5] END n_neighbors=3, p=2, weights=distance;, score=0.922 total time=   0.0s
# [CV 2/5] END n_neighbors=3, p=2, weights=distance;, score=0.924 total time=   0.0s
# [CV 3/5] END n_neighbors=3, p=2, weights=distance;, score=0.924 total time=   0.0s
# [CV 4/5] END n_neighbors=3, p=2, weights=distance;, score=0.927 total time=   0.0s
# [CV 5/5] END n_neighbors=3, p=2, weights=distance;, score=0.916 total time=   0.0s
# [CV 1/5] END n_neighbors=4, p=1, weights=uniform;, score=0.896 total time=   0.1s
# [CV 2/5] END n_neighbors=4, p=1, weights=uniform;, score=0.889 total time=   0.1s
# [CV 3/5] END n_neighbors=4, p=1, weights=uniform;, score=0.887 total time=   0.1s
# [CV 4/5] END n_neighbors=4, p=1, weights=uniform;, score=0.878 total time=   0.1s
# [CV 5/5] END n_neighbors=4, p=1, weights=uniform;, score=0.896 total time=   0.1s
# [CV 1/5] END n_neighbors=4, p=1, weights=distance;, score=0.918 total time=   0.1s
# [CV 2/5] END n_neighbors=4, p=1, weights=distance;, score=0.927 total time=   0.0s
# [CV 3/5] END n_neighbors=4, p=1, weights=distance;, score=0.922 total time=   0.0s
# [CV 4/5] END n_neighbors=4, p=1, weights=distance;, score=0.927 total time=   0.1s
# [CV 5/5] END n_neighbors=4, p=1, weights=distance;, score=0.933 total time=   0.0s
# [CV 1/5] END n_neighbors=4, p=2, weights=uniform;, score=0.889 total time=   0.0s
# [CV 2/5] END n_neighbors=4, p=2, weights=uniform;, score=0.882 total time=   0.0s
# [CV 3/5] END n_neighbors=4, p=2, weights=uniform;, score=0.882 total time=   0.0s
# [CV 4/5] END n_neighbors=4, p=2, weights=uniform;, score=0.880 total time=   0.0s
# [CV 5/5] END n_neighbors=4, p=2, weights=uniform;, score=0.882 total time=   0.0s
# [CV 1/5] END n_neighbors=4, p=2, weights=distance;, score=0.922 total time=   0.0s
# [CV 2/5] END n_neighbors=4, p=2, weights=distance;, score=0.920 total time=   0.0s
# [CV 3/5] END n_neighbors=4, p=2, weights=distance;, score=0.931 total time=   0.0s
# [CV 4/5] END n_neighbors=4, p=2, weights=distance;, score=0.922 total time=   0.0s
# [CV 5/5] END n_neighbors=4, p=2, weights=distance;, score=0.925 total time=   0.0s
# [CV 1/5] END n_neighbors=5, p=1, weights=uniform;, score=0.931 total time=   0.0s
# [CV 2/5] END n_neighbors=5, p=1, weights=uniform;, score=0.938 total time=   0.0s
# [CV 3/5] END n_neighbors=5, p=1, weights=uniform;, score=0.929 total time=   0.0s
# [CV 4/5] END n_neighbors=5, p=1, weights=uniform;, score=0.936 total time=   0.1s
# [CV 5/5] END n_neighbors=5, p=1, weights=uniform;, score=0.931 total time=   0.1s
# [CV 1/5] END n_neighbors=5, p=1, weights=distance;, score=0.931 total time=   0.0s
# [CV 2/5] END n_neighbors=5, p=1, weights=distance;, score=0.938 total time=   0.1s
# [CV 3/5] END n_neighbors=5, p=1, weights=distance;, score=0.927 total time=   0.1s
# [CV 4/5] END n_neighbors=5, p=1, weights=distance;, score=0.938 total time=   0.0s
# [CV 5/5] END n_neighbors=5, p=1, weights=distance;, score=0.933 total time=   0.0s
# [CV 1/5] END n_neighbors=5, p=2, weights=uniform;, score=0.924 total time=   0.0s
# [CV 2/5] END n_neighbors=5, p=2, weights=uniform;, score=0.938 total time=   0.0s
# [CV 3/5] END n_neighbors=5, p=2, weights=uniform;, score=0.938 total time=   0.0s
# [CV 4/5] END n_neighbors=5, p=2, weights=uniform;, score=0.931 total time=   0.0s
# [CV 5/5] END n_neighbors=5, p=2, weights=uniform;, score=0.914 total time=   0.0s
# [CV 1/5] END n_neighbors=5, p=2, weights=distance;, score=0.924 total time=   0.0s
# [CV 2/5] END n_neighbors=5, p=2, weights=distance;, score=0.940 total time=   0.0s
# [CV 3/5] END n_neighbors=5, p=2, weights=distance;, score=0.938 total time=   0.0s
# [CV 4/5] END n_neighbors=5, p=2, weights=distance;, score=0.929 total time=   0.0s
# [CV 5/5] END n_neighbors=5, p=2, weights=distance;, score=0.920 total time=   0.0s
# [CV 1/5] END n_neighbors=6, p=1, weights=uniform;, score=0.904 total time=   0.0s
# [CV 2/5] END n_neighbors=6, p=1, weights=uniform;, score=0.916 total time=   0.0s
# [CV 3/5] END n_neighbors=6, p=1, weights=uniform;, score=0.907 total time=   0.1s
# [CV 4/5] END n_neighbors=6, p=1, weights=uniform;, score=0.905 total time=   0.0s
# [CV 5/5] END n_neighbors=6, p=1, weights=uniform;, score=0.909 total time=   0.0s
# [CV 1/5] END n_neighbors=6, p=1, weights=distance;, score=0.927 total time=   0.0s
# [CV 2/5] END n_neighbors=6, p=1, weights=distance;, score=0.938 total time=   0.0s
# [CV 3/5] END n_neighbors=6, p=1, weights=distance;, score=0.927 total time=   0.1s
# [CV 4/5] END n_neighbors=6, p=1, weights=distance;, score=0.933 total time=   0.0s
# [CV 5/5] END n_neighbors=6, p=1, weights=distance;, score=0.936 total time=   0.0s
# [CV 1/5] END n_neighbors=6, p=2, weights=uniform;, score=0.891 total time=   0.0s
# [CV 2/5] END n_neighbors=6, p=2, weights=uniform;, score=0.898 total time=   0.0s
# [CV 3/5] END n_neighbors=6, p=2, weights=uniform;, score=0.909 total time=   0.0s
# [CV 4/5] END n_neighbors=6, p=2, weights=uniform;, score=0.905 total time=   0.0s
# [CV 5/5] END n_neighbors=6, p=2, weights=uniform;, score=0.894 total time=   0.0s
# [CV 1/5] END n_neighbors=6, p=2, weights=distance;, score=0.922 total time=   0.0s
# [CV 2/5] END n_neighbors=6, p=2, weights=distance;, score=0.927 total time=   0.0s
# [CV 3/5] END n_neighbors=6, p=2, weights=distance;, score=0.940 total time=   0.0s
# [CV 4/5] END n_neighbors=6, p=2, weights=distance;, score=0.931 total time=   0.0s
# [CV 5/5] END n_neighbors=6, p=2, weights=distance;, score=0.922 total time=   0.0s
# [CV 1/5] END n_neighbors=7, p=1, weights=uniform;, score=0.924 total time=   0.0s
# [CV 2/5] END n_neighbors=7, p=1, weights=uniform;, score=0.938 total time=   0.1s
# [CV 3/5] END n_neighbors=7, p=1, weights=uniform;, score=0.920 total time=   0.1s
# [CV 4/5] END n_neighbors=7, p=1, weights=uniform;, score=0.931 total time=   0.1s
# [CV 5/5] END n_neighbors=7, p=1, weights=uniform;, score=0.933 total time=   0.0s
# [CV 1/5] END n_neighbors=7, p=1, weights=distance;, score=0.927 total time=   0.1s
# [CV 2/5] END n_neighbors=7, p=1, weights=distance;, score=0.938 total time=   0.1s
# [CV 3/5] END n_neighbors=7, p=1, weights=distance;, score=0.924 total time=   0.1s
# [CV 4/5] END n_neighbors=7, p=1, weights=distance;, score=0.931 total time=   0.1s
# [CV 5/5] END n_neighbors=7, p=1, weights=distance;, score=0.938 total time=   0.1s
# [CV 1/5] END n_neighbors=7, p=2, weights=uniform;, score=0.920 total time=   0.0s
# [CV 2/5] END n_neighbors=7, p=2, weights=uniform;, score=0.929 total time=   0.0s
# [CV 3/5] END n_neighbors=7, p=2, weights=uniform;, score=0.922 total time=   0.0s
# [CV 4/5] END n_neighbors=7, p=2, weights=uniform;, score=0.920 total time=   0.0s
# [CV 5/5] END n_neighbors=7, p=2, weights=uniform;, score=0.925 total time=   0.0s
# [CV 1/5] END n_neighbors=7, p=2, weights=distance;, score=0.929 total time=   0.0s
# [CV 2/5] END n_neighbors=7, p=2, weights=distance;, score=0.929 total time=   0.0s
# [CV 3/5] END n_neighbors=7, p=2, weights=distance;, score=0.924 total time=   0.0s
# [CV 4/5] END n_neighbors=7, p=2, weights=distance;, score=0.929 total time=   0.0s
# [CV 5/5] END n_neighbors=7, p=2, weights=distance;, score=0.927 total time=   0.0s
# [CV 1/5] END n_neighbors=8, p=1, weights=uniform;, score=0.913 total time=   0.1s
# [CV 2/5] END n_neighbors=8, p=1, weights=uniform;, score=0.913 total time=   0.1s
# [CV 3/5] END n_neighbors=8, p=1, weights=uniform;, score=0.902 total time=   0.1s
# [CV 4/5] END n_neighbors=8, p=1, weights=uniform;, score=0.907 total time=   0.1s
# [CV 5/5] END n_neighbors=8, p=1, weights=uniform;, score=0.907 total time=   0.1s
# [CV 1/5] END n_neighbors=8, p=1, weights=distance;, score=0.931 total time=   0.1s
# [CV 2/5] END n_neighbors=8, p=1, weights=distance;, score=0.929 total time=   0.1s
# [CV 3/5] END n_neighbors=8, p=1, weights=distance;, score=0.929 total time=   0.1s
# [CV 4/5] END n_neighbors=8, p=1, weights=distance;, score=0.929 total time=   0.1s
# [CV 5/5] END n_neighbors=8, p=1, weights=distance;, score=0.931 total time=   0.1s
# [CV 1/5] END n_neighbors=8, p=2, weights=uniform;, score=0.898 total time=   0.0s
# [CV 2/5] END n_neighbors=8, p=2, weights=uniform;, score=0.911 total time=   0.0s
# [CV 3/5] END n_neighbors=8, p=2, weights=uniform;, score=0.909 total time=   0.0s
# [CV 4/5] END n_neighbors=8, p=2, weights=uniform;, score=0.909 total time=   0.0s
# [CV 5/5] END n_neighbors=8, p=2, weights=uniform;, score=0.900 total time=   0.0s
# [CV 1/5] END n_neighbors=8, p=2, weights=distance;, score=0.920 total time=   0.0s
# [CV 2/5] END n_neighbors=8, p=2, weights=distance;, score=0.924 total time=   0.0s
# [CV 3/5] END n_neighbors=8, p=2, weights=distance;, score=0.938 total time=   0.0s
# [CV 4/5] END n_neighbors=8, p=2, weights=distance;, score=0.927 total time=   0.0s
# [CV 5/5] END n_neighbors=8, p=2, weights=distance;, score=0.922 total time=   0.0s
# [CV 1/5] END n_neighbors=9, p=1, weights=uniform;, score=0.920 total time=   0.1s
# [CV 2/5] END n_neighbors=9, p=1, weights=uniform;, score=0.942 total time=   0.1s
# [CV 3/5] END n_neighbors=9, p=1, weights=uniform;, score=0.924 total time=   0.1s
# [CV 4/5] END n_neighbors=9, p=1, weights=uniform;, score=0.931 total time=   0.1s
# [CV 5/5] END n_neighbors=9, p=1, weights=uniform;, score=0.927 total time=   0.1s
# [CV 1/5] END n_neighbors=9, p=1, weights=distance;, score=0.924 total time=   0.1s
# [CV 2/5] END n_neighbors=9, p=1, weights=distance;, score=0.938 total time=   0.1s
# [CV 3/5] END n_neighbors=9, p=1, weights=distance;, score=0.929 total time=   0.1s
# [CV 4/5] END n_neighbors=9, p=1, weights=distance;, score=0.933 total time=   0.1s
# [CV 5/5] END n_neighbors=9, p=1, weights=distance;, score=0.925 total time=   0.1s
# [CV 1/5] END n_neighbors=9, p=2, weights=uniform;, score=0.916 total time=   0.0s
# [CV 2/5] END n_neighbors=9, p=2, weights=uniform;, score=0.924 total time=   0.0s
# [CV 3/5] END n_neighbors=9, p=2, weights=uniform;, score=0.927 total time=   0.0s
# [CV 4/5] END n_neighbors=9, p=2, weights=uniform;, score=0.925 total time=   0.0s
# [CV 5/5] END n_neighbors=9, p=2, weights=uniform;, score=0.918 total time=   0.0s
# [CV 1/5] END n_neighbors=9, p=2, weights=distance;, score=0.920 total time=   0.0s
# [CV 2/5] END n_neighbors=9, p=2, weights=distance;, score=0.931 total time=   0.0s
# [CV 3/5] END n_neighbors=9, p=2, weights=distance;, score=0.933 total time=   0.0s
# [CV 4/5] END n_neighbors=9, p=2, weights=distance;, score=0.929 total time=   0.0s
# [CV 5/5] END n_neighbors=9, p=2, weights=distance;, score=0.925 total time=   0.0s
# [CV 1/5] END n_neighbors=10, p=1, weights=uniform;, score=0.911 total time=   0.1s
# [CV 2/5] END n_neighbors=10, p=1, weights=uniform;, score=0.924 total time=   0.1s
# [CV 3/5] END n_neighbors=10, p=1, weights=uniform;, score=0.902 total time=   0.1s
# [CV 4/5] END n_neighbors=10, p=1, weights=uniform;, score=0.922 total time=   0.1s
# [CV 5/5] END n_neighbors=10, p=1, weights=uniform;, score=0.907 total time=   0.1s
# [CV 1/5] END n_neighbors=10, p=1, weights=distance;, score=0.924 total time=   0.1s
# [CV 2/5] END n_neighbors=10, p=1, weights=distance;, score=0.936 total time=   0.1s
# [CV 3/5] END n_neighbors=10, p=1, weights=distance;, score=0.924 total time=   0.1s
# [CV 4/5] END n_neighbors=10, p=1, weights=distance;, score=0.931 total time=   0.1s
# [CV 5/5] END n_neighbors=10, p=1, weights=distance;, score=0.927 total time=   0.1s
# [CV 1/5] END n_neighbors=10, p=2, weights=uniform;, score=0.902 total time=   0.0s
# [CV 2/5] END n_neighbors=10, p=2, weights=uniform;, score=0.909 total time=   0.0s
# [CV 3/5] END n_neighbors=10, p=2, weights=uniform;, score=0.909 total time=   0.0s
# [CV 4/5] END n_neighbors=10, p=2, weights=uniform;, score=0.911 total time=   0.0s
# [CV 5/5] END n_neighbors=10, p=2, weights=uniform;, score=0.911 total time=   0.0s
# [CV 1/5] END n_neighbors=10, p=2, weights=distance;, score=0.916 total time=   0.0s
# [CV 2/5] END n_neighbors=10, p=2, weights=distance;, score=0.931 total time=   0.0s
# [CV 3/5] END n_neighbors=10, p=2, weights=distance;, score=0.936 total time=   0.0s
# [CV 4/5] END n_neighbors=10, p=2, weights=distance;, score=0.929 total time=   0.0s
# [CV 5/5] END n_neighbors=10, p=2, weights=distance;, score=0.931 total time=   0.0s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 4, 5, 6, 7, 8, 9, 10], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              scoring='recall', verbose=5)

# %%
print(knn_grid_best_params)
print(knn_grid_best_score)
# Out:
# {'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.933390490268539

# %% [markdown]
# ### ANNs

# %%
def ann_random_search (ann_model, X, y):

  ann_parems = {'batch_size' : [10, 16, 32, 64, 128],
                'model__L1_units':[8, 16, 32, 64],
                'model__L2_units': [4, 8, 16],
                'model__alpha': loguniform(1e-4, 1e-1),
                'model__learning_rate_init': loguniform(1e-3, 1e-1)
              }

  Searching = RandomizedSearchCV(estimator= ann_model,
                                    param_distributions= ann_parems,
                                    cv=stratified_kfold,
                                    scoring='recall',
                                    verbose = 5,
                                    random_state=42,
                                    n_jobs=-1,
                                    n_iter=10)
  Searching.fit(X, y)

  return Searching.best_params_ , Searching.best_score_

ann_bestRandom_params, ann_bestRandom_score = ann_random_search(custom_ann_model, X_trans_train[trans_selected_feature_no_redun], y_trans_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# /usr/local/lib/python3.13/dist-packages/joblib/externals/loky/process_executor.py:787: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Epoch 1/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.4561
# Epoch 2/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4250
# Epoch 3/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3795
# Epoch 4/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3724
# Epoch 5/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3589
# Epoch 6/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3490
# Epoch 7/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3304
# Epoch 8/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3269
# Epoch 9/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3166
# Epoch 10/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3115
# Epoch 11/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3079
# Epoch 12/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2997
# Epoch 13/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2969
# Epoch 14/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2928
# Epoch 15/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2867
# Epoch 16/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2887
# Epoch 17/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2796
# Epoch 18/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2740
# Epoch 19/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2721
# Epoch 20/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2646
# Epoch 21/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2565
# Epoch 22/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2551
# Epoch 23/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2483
# Epoch 24/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2475
# Epoch 25/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2517
# Epoch 26/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2397
# Epoch 27/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2389
# Epoch 28/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2385
# Epoch 29/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2327
# Epoch 30/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2340
# Epoch 31/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2351
# Epoch 32/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2328
# Epoch 33/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2290
# Epoch 34/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2233
# Epoch 35/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2196
# Epoch 36/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2186
# Epoch 37/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2267
# Epoch 38/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2326
# Epoch 39/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2196
# Epoch 40/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2189
# Epoch 41/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2170
# Epoch 42/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2243
# Epoch 43/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2176
# Epoch 44/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2202
# Epoch 45/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2079
# Epoch 46/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2149
# Epoch 47/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2056
# Epoch 48/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2046
# Epoch 49/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2082
# Epoch 50/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2036
# Epoch 51/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2031
# Epoch 52/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2072
# Epoch 53/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2024
# Epoch 54/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1999
# Epoch 55/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2088
# Epoch 56/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2020
# Epoch 57/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1988
# Epoch 58/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1959
# Epoch 59/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1984
# Epoch 60/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2030
# Epoch 61/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1956
# Epoch 62/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1927
# Epoch 63/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1924
# Epoch 64/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1995
# Epoch 65/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1901
# Epoch 66/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1920
# Epoch 67/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1962
# Epoch 68/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1932
# Epoch 69/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1890
# Epoch 70/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1864
# Epoch 71/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1923
# Epoch 72/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2007
# Epoch 73/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1911
# Epoch 74/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1887
# Epoch 75/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1927
# Epoch 76/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1861
# Epoch 77/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1840
# Epoch 78/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1797
# Epoch 79/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1795
# Epoch 80/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1856
# Epoch 81/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1845
# Epoch 82/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1786
# Epoch 83/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1767
# Epoch 84/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1816
# Epoch 85/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1867
# Epoch 86/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1870
# Epoch 87/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1873
# Epoch 88/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1879
# Epoch 89/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1819
# Epoch 90/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1828
# Epoch 91/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1837
# Epoch 92/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1792
# Epoch 93/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1853
# Epoch 94/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1761
# Epoch 95/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1790
# Epoch 96/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1763
# Epoch 97/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1730
# Epoch 98/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1763
# Epoch 99/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1729
# Epoch 100/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1725

# %%
print(ann_bestRandom_params)
print(ann_bestRandom_score)
# Out:
# {'batch_size': 64, 'model__L1_units': 8, 'model__L2_units': 16, 'model__alpha': np.float64(0.015702970884055395), 'model__learning_rate_init': np.float64(0.015751320499779727)}
# 0.9729026853904903

# %%
def ann_grid_search (bestRandom_params, ann_model, X, y):

  batch_size = bestRandom_params['batch_size']
  L1_units = bestRandom_params['model__L1_units']
  L2_units = bestRandom_params['model__L2_units']
  alpha = bestRandom_params['model__alpha']
  learning_rate_init = bestRandom_params['model__learning_rate_init']

  ann_parems = {'batch_size' : [batch_size],
              'model__L1_units':[L1_units, L1_units*2, L1_units*4],
              'model__L2_units':[L2_units, L2_units*2, L2_units*4],
              'model__alpha': [alpha],
              'model__learning_rate_init': [learning_rate_init]
              }

  Searching = GridSearchCV(estimator= ann_model,
                                    param_grid = ann_parems,
                                    cv=stratified_kfold,
                                    scoring='recall',
                                    verbose = 5,
                                    n_jobs=-1)

  Searching.fit(X, y)

  return Searching.best_params_ , Searching.best_score_

ann_grid_best_params, ann_grid_best_score = ann_grid_search(ann_bestRandom_params , custom_ann_model, X_trans_train[trans_selected_feature_no_redun], y_trans_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# /usr/local/lib/python3.13/dist-packages/joblib/externals/loky/process_executor.py:787: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Epoch 1/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.0342
# Epoch 2/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4077
# Epoch 3/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3745
# Epoch 4/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3579
# Epoch 5/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3409
# Epoch 6/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3361
# Epoch 7/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3241
# Epoch 8/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3164
# Epoch 9/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3125
# Epoch 10/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2886
# Epoch 11/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2856
# Epoch 12/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2726
# Epoch 13/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2709
# Epoch 14/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2659
# Epoch 15/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2623
# Epoch 16/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2640
# Epoch 17/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2618
# Epoch 18/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2489
# Epoch 19/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2499
# Epoch 20/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2401
# Epoch 21/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2437
# Epoch 22/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2384
# Epoch 23/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2321
# Epoch 24/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2085
# Epoch 25/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2065
# Epoch 26/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1953
# Epoch 27/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1871
# Epoch 28/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1820
# Epoch 29/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1772
# Epoch 30/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1741
# Epoch 31/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1864
# Epoch 32/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1700
# Epoch 33/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1741
# Epoch 34/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1788
# Epoch 35/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1634
# Epoch 36/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1610
# Epoch 37/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1629
# Epoch 38/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1654
# Epoch 39/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1561
# Epoch 40/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1563
# Epoch 41/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1515
# Epoch 42/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1568
# Epoch 43/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1507
# Epoch 44/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1516
# Epoch 45/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1478
# Epoch 46/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1512
# Epoch 47/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1476
# Epoch 48/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1445
# Epoch 49/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1604
# Epoch 50/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1452
# Epoch 51/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1435
# Epoch 52/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1454
# Epoch 53/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1419
# Epoch 54/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1420
# Epoch 55/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1433
# Epoch 56/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1404
# Epoch 57/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1446
# Epoch 58/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1384
# Epoch 59/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1390
# Epoch 60/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1467
# Epoch 61/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1378
# Epoch 62/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1328
# Epoch 63/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1328
# Epoch 64/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1346
# Epoch 65/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1377
# Epoch 66/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1518
# Epoch 67/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1297
# Epoch 68/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1301
# Epoch 69/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1287
# Epoch 70/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1287
# Epoch 71/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1284
# Epoch 72/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1314
# Epoch 73/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1328
# Epoch 74/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1289
# Epoch 75/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1382
# Epoch 76/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1245
# Epoch 77/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1310
# Epoch 78/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1314
# Epoch 79/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1231
# Epoch 80/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1282
# Epoch 81/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1284
# Epoch 82/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1296
# Epoch 83/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1226
# Epoch 84/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1183
# Epoch 85/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1196
# Epoch 86/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1131
# Epoch 87/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1216
# Epoch 88/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1194
# Epoch 89/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1530
# Epoch 90/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1245
# Epoch 91/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1182
# Epoch 92/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1181
# Epoch 93/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1175
# Epoch 94/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1128
# Epoch 95/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1176
# Epoch 96/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1196
# Epoch 97/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1150
# Epoch 98/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1164
# Epoch 99/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1195
# Epoch 100/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1108

# %%
print(ann_grid_best_params)
print(ann_grid_best_score)
# Out:
# {'batch_size': 64, 'model__L1_units': 16, 'model__L2_units': 32, 'model__alpha': np.float64(0.015702970884055395), 'model__learning_rate_init': np.float64(0.015751320499779727)}
# 0.9742468588322246
